# %% [markdown]
# ### General Performance Analysis
# 1. What is the overall proficiency rate (Level 3 and above) across all subjects in the latest year?
# 2. Which demographic subgroup has the highest proficiency rate across all subjects?
# 3. How does student performance vary across different performance levels (Level 1, Level 2, etc.)?
# 4. What percentage of students scored proficient (Level 3 and above) in Math compared to ELA?
# 5. Are there differences in the mean scores for students in elementary/middle school (EM) versus high school (HS)?

# %% [markdown]
# #### Overall Proficiency Rate Across All Subjects

# %%
import pandas as pd

# %%
# Load data
data_ela = pd.read_excel(r'E:\Data Analytics\NYSE Report Card\Annual_EM_ELA.xlsx')

# %%
data_math = pd.read_excel(r'E:\Data Analytics\NYSE Report Card\Annual_EM_MATH.xlsx')

# %%
data_science = pd.read_excel(r'E:\Data Analytics\NYSE Report Card\Annual_EM_SCIENCE.xlsx')

# %%
data_ela.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD  \
# 0             NaN          1
# 1             NaN          1
# 2             NaN          1
# 3             NaN          1
# 4             NaN          1
#
#                                          ENTITY_NAME  YEAR ASSESSMENT_NAME  \
# 0  High Need/Resource Category: New York City Dis...  2023            ELA6
# 1  High Need/Resource Category: New York City Dis...  2023            ELA8
# 2  High Need/Resource Category: New York City Dis...  2023            ELA7
# 3  High Need/Resource Category: New York City Dis...  2023            ELA4
# 4  High Need/Resource Category: New York City Dis...  2023          ELA3_8
#
#   SUBGROUP_NAME  TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  ...  \
# 0  All Students        59583        7757            13.0       51826  ...
# 1  All Students        64216       10495            16.0       53721  ...
# 2  All Students        61290        7945            13.0       53345  ...
# ...

# %%
data_math.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD  \
# 0             NaN          1
# 1             NaN          1
# 2             NaN          1
# 3             NaN          1
# 4             NaN          1
#
#                                          ENTITY_NAME  YEAR ASSESSMENT_NAME  \
# 0  High Need/Resource Category: New York City Dis...  2023           MATH5
# 1  High Need/Resource Category: New York City Dis...  2023         MATH3_8
# 2  High Need/Resource Category: New York City Dis...  2023   Combined6Math
# 3  High Need/Resource Category: New York City Dis...  2023    RegentsMath7
# 4  High Need/Resource Category: New York City Dis...  2023   Combined8Math
#
#   SUBGROUP_NAME  TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  ...  \
# 0  All Students      61807.0      6791.0            11.0       55016  ...
# 1  All Students     365267.0     41489.0            11.0      323778  ...
# 2  All Students      59693.0      6311.0            11.0       53382  ...
# ...

# %%
data_science.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD  \
# 0             NaN          1
# 1             NaN          1
# 2             NaN          1
# 3             NaN          1
# 4             NaN          1
#
#                                          ENTITY_NAME  YEAR   ASSESSMENT_NAME  \
# 0  High Need/Resource Category: New York City Dis...  2023   RegentsScience8
# 1  High Need/Resource Category: New York City Dis...  2023  CombinedScience
# 2  High Need/Resource Category: New York City Dis...  2023          Science8
# 3  High Need/Resource Category: New York City Dis...  2023          Science8
# 4  High Need/Resource Category: New York City Dis...  2023          Science8
#
#                                      SUBGROUP_NAME  TOTAL_COUNT  NOT_TESTED  \
# 0                                     All Students          NaN         NaN
# 1                                     All Students      64492.0     10095.0
# 2                                     All Students      64492.0     32441.0
# ...

# %%
# Combine data
all_subjects = pd.concat([data_ela, data_math, data_science])

# %%
# Overall proficiency rate
all_subjects['PER_PROF'] = pd.to_numeric(all_subjects['PER_PROF'], errors = 'coerce')

# %%
overall_proficiency = all_subjects['PER_PROF'].mean()

# %%
print(f"Overall Proficiency Rate: {overall_proficiency:.2f}%")
# Out:
# Overall Proficiency Rate: 45.21%

# %% [markdown]
# #### Highest Proficiency Rate Across Demographic Subgroups

# %%
# Group by subgroup and calculate mean proficiency
subgroup_proficiency = all_subjects.groupby("SUBGROUP_NAME")["PER_PROF"].mean()
subgroup_proficiency
# Out:
# SUBGROUP_NAME
# All Students                                       50.070436
# American Indian or Alaska Native                   40.372934
# Asian or Native Hawaiian/Other Pacific Islander    67.739423
# Black or African American                          34.892672
# Economically Disadvantaged                         38.734379
# English Language Learner                           15.500968
# Female                                             48.245494
# General Education Students                         52.026929
# Hispanic or Latino                                 39.226079
# Homeless                                           29.029497
# In Foster Care                                     20.697630
# Male                                               45.719637
# Migrant                                            15.296520
# Multiracial                                        48.378011
# Non-Binary                                         67.973684
# ...

# %%
top_subgroup = subgroup_proficiency.idxmax()
top_subgroup
# Out:
# 'Non-Binary'

# %%
top_subgroup_rate = subgroup_proficiency.max()
top_subgroup_rate
# Out:
# 67.97368421052632

# %%
print(f"Highest Proficiency Rate: {top_subgroup} with {top_subgroup_rate: .2f}%")
# Out:
# Highest Proficiency Rate: Non-Binary with  67.97%

# %% [markdown]
# #### Performance Distribution Across Levels

# %%
# Compute performance levels distribution
performance_levels = all_subjects[["LEVEL1_%TESTED", "LEVEL2_%TESTED", "LEVEL3_%TESTED", "LEVEL4_%TESTED"]]
performance_levels = performance_levels.apply(pd.to_numeric, errors = 'coerce')
level_distribution = performance_levels.mean()
print("Performance Levels Distribution: \n", level_distribution)
# Out:
# Performance Levels Distribution:
#  LEVEL1_%TESTED    26.404210
# LEVEL2_%TESTED    28.412798
# LEVEL3_%TESTED    31.221050
# LEVEL4_%TESTED    13.805365
# dtype: float64

# %% [markdown]
# #### Math vs ELA Proficiency Rates

# %%
# Ensure the proficiency percentages are numeric
data_math["PER_PROF"] = pd.to_numeric(data_math["PER_PROF"], errors="coerce")
data_ela["PER_PROF"] = pd.to_numeric(data_ela["PER_PROF"], errors="coerce")

# Calculate the mean proficiency rates
math_proficiency = data_math["PER_PROF"].mean()
ela_proficiency = data_ela["PER_PROF"].mean()

# Print the results
print(f"Math Proficiency: {math_proficiency:.2f}%")
print(f"ELA Proficiency: {ela_proficiency:.2f}%")
# Out:
# Math Proficiency: 48.31%
# ELA Proficiency: 43.36%

# %% [markdown]
# #### EM vs HS Mean Scores

# %%
# Filter for EM and HS data
em_data = all_subjects[all_subjects["ASSESSMENT_NAME"].str.contains("EM", na=False)]
hs_data = all_subjects[~all_subjects["ASSESSMENT_NAME"].str.contains("EM", na=False)]

# %%
# Compute mean scores
em_data["MEAN_SCORE"] = pd.to_numeric(em_data["MEAN_SCORE"], errors = 'coerce')
hs_data["MEAN_SCORE"] = pd.to_numeric(hs_data["MEAN_SCORE"], errors='coerce')

# %%
# Compute mean scores
em_mean_score = em_data["MEAN_SCORE"].mean()
hs_mean_score = hs_data["MEAN_SCORE"].mean()

# %%
print(f"EM Mean Score: {em_mean_score:.2f}")
print(f"HS Mean Score: {hs_mean_score:.2f}")
# Out:
# EM Mean Score: nan
# HS Mean Score: 436.59
